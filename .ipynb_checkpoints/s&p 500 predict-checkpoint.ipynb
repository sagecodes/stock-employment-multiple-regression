# %% [markdown]
# ### Import Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import data
data_df = pd.read_csv('../datasets/SandP500/S&P500_Stock_Data.csv')

# %%
data_df.head()
# Out:
#    Interest Rates  Employment  S&P 500 Price
# 0        1.943859   55.413571    2206.680582
# 1        2.258229   59.546305    2486.474488
# 2        2.215863   57.414687    2405.868337
# 3        1.977960   49.908353    2140.434475
# 4        2.437723   52.035492    2411.275663

# %%
data_df.shape
# Out:
# (1000, 3)

# %% [markdown]
# ### Explore data

# %%
data_df.describe()
# Out:
#        Interest Rates   Employment  S&P 500 Price
# count     1000.000000  1000.000000    1000.000000
# mean         2.195392    56.254855    2319.999936
# std          0.241630     4.862178     193.854745
# min          1.500000    40.000000    1800.000000
# 25%          2.035735    53.029784    2190.447901
# 50%          2.198214    56.160941    2312.443024
# 75%          2.359061    59.422633    2455.764327
# max          3.000000    70.000000    3000.000000

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
# Interest Rates    1000 non-null float64
# Employment        1000 non-null float64
# S&P 500 Price     1000 non-null float64
# dtypes: float64(3)
# memory usage: 23.5 KB

# %%
sns.pairplot(data_df)

# %% [markdown]
# ### Data Prep

# %%
X = data_df.drop(['S&P 500 Price'], axis = 1)

# %%
y = data_df['S&P 500 Price']

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
X.head()
# Out:
#    Interest Rates  Employment
# 0        1.943859   55.413571
# 1        2.258229   59.546305
# 2        2.215863   57.414687
# 3        1.977960   49.908353
# 4        2.437723   52.035492

# %%
y.head()
# Out:
# 0    2206.680582
# 1    2486.474488
# 2    2405.868337
# 3    2140.434475
# 4    2411.275663
# Name: S&P 500 Price, dtype: float64

# %%
# Create train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state = 5, stratify=y)

# %%
# Create train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state = 5)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (800, 2)
# (800,)
# (200, 2)
# (200,)

# %% [markdown]
# ### Train and evaluate model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression(fit_intercept=True)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Linear Model Coefficient (m)', reg.coef_)
print('Linear Model Coefficient (b)', reg.intercept_)
# Out:
# Linear Model Coefficient (m) [719.11405075  11.93978975]
# Linear Model Coefficient (b) 69.33688697536627

# %%
y_pred = reg.predict(X_test)

# %%
y_pred.shape
# Out:
# (200,)

# %%
plt.scatter(y_test, y_pred, color = 'r')
plt.ylabel('Model Prediction')
plt.xlabel('True values')
plt.title(' Multiple Linear Regression Predictions')
# Out:
# Text(0.5, 1.0, ' Multiple Linear Regression Predictions')

# %%
# Get number of independent params
k = X_test.shape[1]
# Get length of test data
n = len(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
MSE = float(format(mean_squared_error(y_test, y_pred), '.3f'))
MAE = float(format(mean_absolute_error(y_test, y_pred), '.3f'))
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
adj_r2 = float(format(1-(1-r2)*(n-1)/(n-k-1), '.3f'))
MAPE = float(format(np.mean(np.abs((y_test-y_pred)/y_test))*100, '.3f'))

# %%
print('RMSE: ', RMSE)
print('MSE: ', MSE)
print('MAE: ', MAE)
print('r2: ', r2)
print('adj_r2: ', adj_r2)
print('MAPE: ', MAPE)
# Out:
# RMSE:  59.987
# MSE:  3598.494
# MAE:  47.861
# r2:  0.915
# adj_r2:  0.914
# MAPE:  2.075

# %%
## 3D PLOT

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid(np.linspace(data_df['Interest Rates'].min(), 
                                         data_df['Interest Rates'].max(),100),
                             np.linspace(data_df['Employment'].min(), 
                                         data_df['Employment'].max(), 100))

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
# flatten
onlyX = pd.DataFrame({'Interest rates':x_surf.ravel(), 'Employment':y_surf.ravel()})

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
fity = reg.predict(onlyX)

# %%
fity.shape
# Out:
# (10000,)

# %%
fity = fity.reshape(x_surf.shape)

# %%
fity.shape
# Out:
# (100, 100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(data_df['Interest Rates'], data_df['Employment'], data_df['S&P 500 Price'], c = 'blue', marker = 'x')
ax.plot_surface(x_surf, y_surf, fity, color = 'red', alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_xlabel('Unemployment Rates')
ax.set_xlabel('Stock Index Price')
# Out:
# Text(0.5, 0, 'Stock Index Price')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(data_df['Interest Rates'], data_df['Employment'], data_df['S&P 500 Price'], c = 'blue', marker = 'x')
ax.plot_surface(x_surf, y_surf, fity, color = 'red', alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_xlabel('Unemployment Rates')
ax.set_xlabel('Stock Index Price')
ax.view_init(20, 30)
plt.show()

# %%
coeff_df = pd.DataFrame(reg.coef_, X.columns, columns = ['Coefficient'])

# %%
coeff_df
# Out:
#                 Coefficient
# Interest Rates   719.114051
# Employment        11.939790
